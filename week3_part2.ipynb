# %% [markdown]
# ## Scraping the data
#
# Scrape the data from the wikipedia page and convert it to a dataframe

# %%
import pandas as pd
import requests
from bs4 import BeautifulSoup

res = requests.get("https://en.wikipedia.org/wiki/List_of_postal_codes_of_Canada:_M")
soup = BeautifulSoup(res.content,'lxml')
table = soup.find_all('table')[0] 
df = pd.read_html(str(table))[0]
df.head()
# Out:
#   Postal code           Borough                Neighborhood
# 0         M1A      Not assigned                         NaN
# 1         M2A      Not assigned                         NaN
# 2         M3A        North York                   Parkwoods
# 3         M4A        North York            Victoria Village
# 4         M5A  Downtown Toronto  Regent Park / Harbourfront

# %% [markdown]
# ## Cleaning data
# Ignore cells with a borough that is Not assigned

# %%
df = df[df['Borough'] != 'Not assigned']
df.reset_index(inplace=True)
df.head(20)
# Out:
#     index Postal code           Borough  \
# 0       2         M3A        North York
# 1       3         M4A        North York
# 2       4         M5A  Downtown Toronto
# 3       5         M6A        North York
# 4       6         M7A  Downtown Toronto
# 5       8         M9A         Etobicoke
# 6       9         M1B       Scarborough
# 7      11         M3B        North York
# 8      12         M4B         East York
# 9      13         M5B  Downtown Toronto
# 10     14         M6B        North York
# 11     17         M9B         Etobicoke
# 12     18         M1C       Scarborough
# 13     20         M3C        North York
# 14     21         M4C         East York
# 15     22         M5C  Downtown Toronto
# 16     23         M6C              York
# 17     26         M9C         Etobicoke
# 18     27         M1E       Scarborough
# 19     30         M4E      East Toronto
#
#                                          Neighborhood
# 0                                           Parkwoods
# ...

# %% [markdown]
# ## Merging data

# %%
df = df.groupby(['Postal code', 'Borough'])['Neighborhood'].apply(', '.join).reset_index()
df.head()
# Out:
#   Postal code      Borough                              Neighborhood
# 0         M1B  Scarborough                           Malvern / Rouge
# 1         M1C  Scarborough  Rouge Hill / Port Union / Highland Creek
# 2         M1E  Scarborough       Guildwood / Morningside / West Hill
# 3         M1G  Scarborough                                    Woburn
# 4         M1H  Scarborough                                 Cedarbrae

# %% [markdown]
# ## Printing the shape of the data

# %%
df.shape
# Out:
# (103, 3)

# %% [markdown]
# ## Merging data
# Merging the original dataframe with the geosapatial data

# %%
geo_df = pd.read_csv("http://cocl.us/Geospatial_data")
geo_df.columns=['Postal code', 'Latitude', 'Longitude']
geo_df.head()

# %%
new_df = pd.merge(df, geo_df, on='Postal code', how='outer')
new_df.head()
